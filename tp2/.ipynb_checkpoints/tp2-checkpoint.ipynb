# %%
import tp2_functions

# %%
word_stream = tp2_functions.File_word_stream('../data/20ng.utf8.txt')

# %%
k = 100

# %%
reservoir_sampling1 = tp2_functions.R_reservoir_sampling(k)

# %%
reservoir_sampling1.fill_reservoir_from_word_stream(word_stream)

# %%
reservoir_sampling1.plot_sorted_positions()

# %%
word_count = tp2_functions.WordCount(word_stream)

# %%
reservoir_sampling1.plot_against_word_count(word_stream, word_count)

# %%
hash_bucket_counter = tp2_functions.Hash_bucket_counter(1024)

# %%
hash_bucket_counter.try_insert_from_word_stream(word_stream)

# %%
hash_bucket_counter.print_counter()
# Out:
# [(2807, -9157812696769413792, 'things'), (2623, -9125801931811556222, 'last'), (1673, -9207762856268681578, 'software'), (912, -9195106614977744458, 'Jewish'), (566, -8942870576502182400, 'Graphics'), (437, -9207966513326651242, 'input'), (435, -9037151010006672571, 'events'), (260, -9211217529009479677, 'positive'), (251, -9218035170882903211, 'ice'), (246, -9220030102914265718, 'refer'), (244, -9080373395647780108, 'surprised'), (235, -8969043097118144787, 'reduce'), (211, -9197151915232986938, 'Biblical'), (202, -8970443060006301615, 'ports'), (177, -9130029571921444601, 'atmosphere'), (172, -9139394109642622552, 'usage'), (161, -9154191478918541820, 'Political'), (159, -8830449810585871012, 'cool'), (158, -9161503960374546677, 'massacre'), (158, -9163924119862997654, 'favorite'), (157, -9220678259009488186, 'Mouse'), (154, -9209287597337180959, 'spirit'), (144, -9154457933739147520, 'THAT'), (126, -9216818577666418249, 'Stan'), (122, -9151792686511014848, 'sensitivity'), (119, -9
# ...
